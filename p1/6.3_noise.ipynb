# %%
import torch

# %%
xs = torch.linspace(-5, 5, steps=100)
ys = torch.linspace(-5, 5, steps=100)
x, y = torch.meshgrid(xs, ys, indexing='xy')
x,y
# Out:
# (tensor([[-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#          [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#          [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#          ...,
#          [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#          [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#          [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000]]),
#  tensor([[-5.0000, -5.0000, -5.0000,  ..., -5.0000, -5.0000, -5.0000],
#          [-4.8990, -4.8990, -4.8990,  ..., -4.8990, -4.8990, -4.8990],
#          [-4.7980, -4.7980, -4.7980,  ..., -4.7980, -4.7980, -4.7980],
#          ...,
#          [ 4.7980,  4.7980,  4.7980,  ...,  4.7980,  4.7980,  4.7980],
#          [ 4.8990,  4.8990,  4.8990,  ...,  4.8990,  4.8990,  4.8990],
#          [ 5.0000,  5.0000,  5.0000,  ...,  5.0000,  5.0000,  5.0000]]))

# %%
x
# Out:
# tensor([[-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#         [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#         [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#         ...,
#         [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#         [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000],
#         [-5.0000, -4.8990, -4.7980,  ...,  4.7980,  4.8990,  5.0000]])

# %%
#  TODO:
# uv curve class

# %%
import filepath
from matplotlib import pyplot as plt

# %%
from geom.procedural_art.noise import perlin

# %%
perlin_noise = perlin.perlin_noise(grid_shape=(8, 8), out_shape=(128, 128))
plt.imshow(perlin_noise)

# %%
perlin_noise = perlin.perlin_noise(grid_shape=(4, 4), out_shape=(128, 128))
plt.imshow(perlin_noise)

# %%
# Out:
# tensor([[ 0.0065,  0.0378,  0.0726,  ..., -0.0861, -0.0528, -0.0210],
#         [-0.0046,  0.0268,  0.0617,  ..., -0.1005, -0.0679, -0.0365],
#         [-0.0110,  0.0203,  0.0553,  ..., -0.1184, -0.0869, -0.0562],
#         ...,
#         [-0.0370, -0.0615, -0.0827,  ...,  0.0559,  0.0602,  0.0618],
#         [-0.0291, -0.0541, -0.0756,  ...,  0.0348,  0.0393,  0.0410],
#         [-0.0195, -0.0448, -0.0663,  ...,  0.0088,  0.0134,  0.0152]])

# %%
# TODO: make these generators follow same interface and behaviour

# %%
# todo: constants and tool function
# interpolate

# %%
# use classes
