# %%
# from vispyutil.canvas import SynchronizedCanvas
from vispy import app, scene, visuals, use

# %%
use("glfw")

# %%
import filepath
from vispyutil.canvas import SynchronizedCanvas
