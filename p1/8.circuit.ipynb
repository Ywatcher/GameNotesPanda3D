# %%
def dec(f,a):
    def newfunc(b):
        
        return f(a+b)
    newfunc.__doc__ = f"""
        decorated with {a}
        ----
        {f.__doc__}
        """
    return newfunc

# %%
def fn(a):
    """
    doc
    doc
    """
    pass

# %%
fn.__doc__
# Out:
# '\n    doc\n    doc\n    '

# %%
def gn(a):
    pass

# %%
gn.__doc__

# %%
hn = dec(fn,1)

# %%
hn.__doc__
# Out:
# '\n        decorated with 1\n        ----\n        \n    doc\n    doc\n    \n        '

# %%
help(hn)
# Out:
# Help on function newfunc in module __main__:
#
# newfunc(b)
#         decorated with 1
#         ----
#
#     doc
#     doc
